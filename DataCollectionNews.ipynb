# %%
import requests

URL="https://edition.cnn.com/article/sitemap-2021-3.html"

# %%
page=requests.get(URL)

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page.content, 'html.parser')

# %%
div_containers=soup.findAll(class_='sitemap-entry')
list_container = div_containers[1]
entries = list_container.findAll('li')

dates = ["2021-03-11", "2021-03-12"]

fil_entries = []

for entry in entries:
  if entry.find(class_='date').text.strip() in dates:
    fil_entries.append(entry)

fil_entries
# Out:
# [<li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/tennis/andy-murray-fourth-child-scli-intl-gbr-spt/index.html">Andy Murray pulls out of Dubai Open after arrival of fourth child</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/uk/sarah-everard-body-identified-gbr-intl-scli/index.html">Police identify body of Sarah Everard, who went missing in London</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/sport/esports-lockdown-team-liquid-family-cmd-spt-intl/index.html">&amp;aposThey are like a family&amp;apos: How esports has helped its fans get through lockdown</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/uk/royal-news-newsletter-03-12-21-gbr-intl/index.html">Harry and Meghan&amp;aposs seismic interview will be felt for generations</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/motorsport/mick-schumacher-formula-one-haas-cmd-spt-intl/index.html">Mick Schumacher: A &amp;aposbig privilege&amp;apos to carry legendary surname into Formula One again</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/europe/uk-elderly-pandemic-freedom-gbr-intl/index.html">They can only hold hands, but for Britain&amp;aposs elderly, first touch with a relative &amp;aposmeans everything&amp;apos</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/football/ac-milan-manchester-united-arsenal-europa-league-spt-intl/index.html">&amp;aposExtraordinary&amp;apos AC Milan stuns Manchester United with last-gasp equalizer</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/europe/astrazeneca-vaccine-blood-clot-reports-denmark-reviews-intl/index.html">AstraZeneca says &amp;aposno evidence&amp;apos of blood clot risk from vaccine as countries suspend its use</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/golf/players-championship-17th-hole-byeong-hun-an-spt-intl/index.html">&amp;aposIt was a horrendous tee shot&amp;apos: Players Championship famed 17th hole claims victims</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/tennis/federer-tennis-dubai-injury-spt-intl/index.html">Roger Federer withdraws from upcoming tournament after making his tennis return</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/sport/dr-richard-freeman-british-cycling-spt-intl/index.html">Former British Cycling doctor found guilty of ordering banned testosterone</a></span></li>,
#  <li><span class="date">2021-03-12</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/12/uk/meghan-race-britain-gbr-intl/index.html">Meghan said racism drove her out of the UK. Black Britons ask, &amp;aposare we still here in 2021?&amp;apos</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/11/europe/nazi-guard-trial-harry-s-stutthof-scli-intl-grm/index.html">96-year-old accused of being Nazi camp guard is deemed &amp;aposunfit&amp;apos for trial</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/11/football/nba-meyers-leonard-fine-suspension-spt-intl/index.html">NBA fines Miami Heat star Meyers Leonard $50,000 for anti-Semitic slur and suspends center</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/10/football/cristiano-ronaldo-juventus-porto-champions-league-spt-intl/index.html">Cristiano Ronaldo commits &amp;aposunforgivable error&amp;apos as Juventus is stunned by 10-man Porto in Champions League</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/11/sport/dak-prescott-super-bowl-dallas-cowboys-spt-intl/index.html">Superstar quarterback Dak Prescott eyes Super Bowl parade after signing mega deal</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2013/10/29/world/russia-fast-facts/index.html">Russia Fast Facts</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/11/europe/astrazeneca-vaccine-denmark-suspension-intl/index.html">More European nations pause AstraZeneca vaccine use as blood clot reports investigated</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/11/football/cat-phillips-frisbee-australian-football-gender-equality-cmd-spt-intl/index.html">Frisbee and oval ball star Cat Phillips fired up by fight for gender equality</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/11/europe/lou-ottens-dies-scli-intl/index.html">Dutch inventor of the cassette tape, Lou Ottens, dies age 94</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/11/football/lionel-messi-barcelona-psg-goal-champions-league-spt-intl/index.html">Lionel Messi scores &amp;aposspecial&amp;apos goal but misses penalty as Barcelona crashes out of the Champions League</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/11/uk/sarah-everard-women-harassment-streets-gbr-intl/index.html">Sarah Everard case prompts outpouring from women sharing stories of abuse and harassment on UK streets</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/11/uk/prince-william-response-racism-harry-meghan-intl-gbr/index.html">Prince William says royals are &amp;aposvery much not a racist family&amp;apos in first remarks since explosive interview</a></span></li>,
#  <li><span class="date">2021-03-11</span><span class="sitemap-link"><a href="https://edition.cnn.com/2021/03/11/tennis/tennis-survive-covid-19-money-spt-intl/index.html">&amp;aposWe cannot survive&amp;apos, tennis counts the cost of empty stands</a></span></li>]

# %%
news_json = []

for entry in fil_entries:
  date=entry.find(class_='date').text.strip()

  url=entry.find(class_='sitemap-link').a.get("href")
  page=requests.get(url)
  soup=BeautifulSoup(page.content, 'html.parser')

  title=soup.find("h1", {"class": "pg-headline"}).text.strip()
  author=soup.find("span", {"class": "metadata__byline__author"}).text.strip()
  author=author.replace('By ', '')
  author=author.replace(', CNN', '')
  paragraphs=soup.find_all("div", {"class": "zn-body__paragraph"})
  speakable=soup.find("p", {"class": "zn-body__paragraph speakable"}).text.strip()
  article=speakable
  for i in range(len(paragraphs)):
    article = article + ' ' + paragraphs[i].text.strip()

  news_json.append({
      "date": date,
      "title": title,
      "article": article,
      "author": author,
  })

news_json

# %%
import json
with open('/content/news.json', 'w') as outfile:
    json.dump(news_json, outfile)
